# %%
#Daniel Saravia

Nombre = """

DDDD
D   D
D   D
D   D
D   D
DDDD
"""
print(Nombre)


Apellido = """

SSSSS
S
S
SSSSS
    S
    S
SSSSS
"""
print(Apellido)



#Uva

Fruta = """
      U
     U 
     UU
     U
    U
UUUUUUUUUU
U        U
U        U
U        U 
UUUUUUUUUU
"""
print(Fruta)
# Out:
# DDDD
# D   D
# D   D
# D   D
# D   D
# DDDD
#
#
#
# SSSSS
# S
# S
# SSSSS
#     S
#     S
# SSSSS
#
#
#       U
#      U
#      UU
#      U
#     U
# UUUUUUUUUU
# U        U
# U        U
# U        U
# UUUUUUUUUU

# %%
# Tienda Lovely Loveseat
#1 Descripcion
lovely_loveseat_description = """
Lovely Loveseat. 
Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep. 
Red or white. """

print (lovely_loveseat_description)

#2 Precio
lovely_loveseat_price = 254.00
print (lovely_loveseat_price)



#3 Otro mueble
styling_settee_description="""
Stylish Settee. 
Faux leather on birch. 
29.50 inches high x 54.75 inches wide x 28 inches deep. 
Black.
"""

print(styling_settee_description)

#4 Precio del nuevo mueble
style_settee_price = 180.50
print (style_settee_price)



#5 lampara
luxury_lamp_description = """
Luxurious Lamp. 
Glass and iron. 
36 inches tall. 
Brown with cream shade.
"""
print(luxury_lamp_description)

#6 Precio lampara
luxury_lamp_price = 52.15
print(luxury_lamp_price)

#7 Impuesto
sales_tax = 0.088
print (sales_tax)

#8 y 10, 12 Primer compra
customer_one_total = lovely_loveseat_price + luxury_lamp_price
print (customer_one_total)

#9 y 11, 13 Lista de descripciones
customer_one_itemization = lovely_loveseat_description + luxury_lamp_description
print (customer_one_itemization)

#14 Calcular impuestos
customer_one_tax = customer_one_total * sales_tax
print (round(customer_one_tax, 2))

#15 Suma de vemtas al cliente
customer_one_total = lovely_loveseat_price + luxury_lamp_price + customer_one_tax
print (round(customer_one_total, 2))

#16, 18 Imprimir recibo

print("Customer_One_Items")
print(customer_one_itemization)

#17, 19 Imprima total
print ("customer_one_total")
print (round(customer_one_total, 2))

#20, 22 cliente 2
customer_two_total = style_settee_price
print(customer_two_total)

#21, 23
customer_two_itemization = styling_settee_description
print(customer_two_itemization)

#24
#Descuento Lampara
discount_lamp = luxury_lamp_price - 0.2
print(round(discount_lamp,2))


#Descuento Sofa
discount_lovely = lovely_loveseat_price - 0.15
print (round(discount_lovely,2))
# Out:
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white.
# 254.0
#
# Stylish Settee.
# Faux leather on birch.
# 29.50 inches high x 54.75 inches wide x 28 inches deep.
# Black.
#
# 180.5
#
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade.
#
# 52.15
# 0.088
# 306.15
#
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white.
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade.
#
# 26.94
# 333.09
# Customer_One_Items
#
# Lovely Loveseat.
# Tufted polyester blend on wood. 32 inches high x 40 inches wide x 30 inches deep.
# Red or white.
# Luxurious Lamp.
# Glass and iron.
# 36 inches tall.
# Brown with cream shade.
#
# customer_one_total
# 333.09
# 180.5
#
# Stylish Settee.
# Faux leather on birch.
# 29.50 inches high x 54.75 inches wide x 28 inches deep.
# Black.
#
# 51.95
# 253.85
